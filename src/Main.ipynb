# %%
# !pip install transformers
# !pip install nltk

# %% [markdown]
# <h1><b>Google Colab Setup</b></h1>
# To use Google Colab effectively, you need to set up the necessary libraries and dependencies. This markdown file provides a step-by-step guide on how to set up a Google Colab environment for a specific task.
#
# ## <b>Importing Libraries</b>
# First, you need to import the required libraries. Here are some commonly used libraries for various tasks:

# %%
import csv
import requests
import torch
import pandas as pd
import networkx as nx
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import re
from string import punctuation
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('punkt')
nltk.download('vader_lexicon')

# %% [markdown]
# # **Fetching and Saving Twitter Data**
# To scrape Twitter data for HP India products, you can use the following steps:
#
# 1. Set the API endpoint URL to `https://twitter135.p.rapidapi.com/Search/`.
# 2. Define the query parameters for the search, such as the search `query (q)` and the count of tweets to retrieve `(count)`.
# 3. Set the necessary headers, including the RapidAPI key and host.
# 4. Make a GET request to the Twitter API using the URL, headers, and query parameters.
# 5. Check the response status code to ensure a successful request (status code 200).
# 6. Parse the response JSON to extract the tweets.
# 7. Open a CSV file named 'Twitter_hp_data.csv' in append mode for writing.
# 8. Write the header row with the column names: 'Tweet ID' and 'Full Text'.
# 9. Iterate through the tweets and write the tweet ID and full text to the CSV file.
# 10. Print a message indicating the successful creation of the CSV file.

# %%
url = "https://twitter135.p.rapidapi.com/Search/"

querystring = {"q": "HP India products", "count": "300"}

headers = {
    "X-RapidAPI-Key": "...Enter Your Key...",
    "X-RapidAPI-Host": "twitter135.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    data = response.json()
    tweets = data['globalObjects']['tweets']
    with open('Twitter_hp_data.csv', 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Tweet ID', 'Full Text'])

        for tweet_id, tweet_data in tweets.items():
            tweet_id = tweet_id.strip('"')
            full_text = tweet_data.get('full_text', '')
            writer.writerow([tweet_id, full_text])

    print('CSV file created successfully.')
else:
    print('Error:', response.status_code)

# %% [markdown]
# # **Fetching and Saving Amazon Reviews**
# To scrape Amazon reviews for HP printers, follow these steps:
#
# 1. Define an empty list asin_list to store the ASINs of the HP printers.
# 2. Make a GET request to the Amazon product search API to retrieve the list of HP printers. Use the following endpoint: `https://real-time-amazon-data.p.rapidapi.com/search`. Include the required query parameters for the search, such as the **query, page, country, and category ID. Also, set the necessary headers, including the RapidAPI key and host**.
# 3. Parse the response JSON to extract the ASINs of the HP printers and append them to the asin_list.
# Define an empty dictionary review_list to store the review details.
# 4. Make a GET request to the Amazon product reviews API for each ASIN in the asin_list. Use the following endpoint: `https://real-time-amazon-data.p.rapidapi.com/product-reviews`. Include the required query parameters, such as the ASIN, country, verified purchases only, images or videos only, page, and page size. Set the necessary headers.
# 5. Parse the response JSON to extract the review details, including the review ID, title, and comment. Append them to the respective lists in the review_list dictionary.
# 6. If reviews are not found for a particular ASIN, handle the case and display an appropriate message.
# 7. Write the review details from the review_list to a CSV file named 'amazon_data.csv'. Include the header row with the column names: 'Review_ID', 'Review_Title', and 'Review_comment'.
# 8. Print a message indicating the successful creation of the CSV file.

# %%
asin_list = []
review_list = {
    'review_id':[],
    'review_title':[],
    'review_comment':[]
}

def ids():
    global asin_list
    url = "https://real-time-amazon-data.p.rapidapi.com/search"

    querystring = {"query":"HP Printer","page":"1","country":"IN","category_id":"aps"}

    headers = {
    	"X-RapidAPI-Key": "...Enter Your Key..",
    	"X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    product_list = data['data']['products']
    for asin in product_list:
        asin_list.append(asin['asin'])
    print(asin_list)

def reviews():
    url = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"
    headers = {
        "X-RapidAPI-Key": "...Enter your Key...",
        "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
    }
    for asin in asin_list:
        global review_list
        querystring = {"asin": f"{asin}", "country": "IN", "verified_purchases_only": "false",
                       "images_or_videos_only": "false", "page": "1", "page_size": "1"}
        response = requests.get(url, headers=headers, params=querystring)

        data = response.json()
        # print(data)  # Debug print

        if 'data' in data:
            if 'reviews' in data['data']:
                product_list = data['data']['reviews']
                for ids in product_list:
                    review_list['review_id'].append(ids['review_id'])
                    review_list['review_title'].append(ids['review_title'])
                    review_list['review_comment'].append(ids['review_comment'])
            else:
                print("No reviews found for ASIN:", asin)
        else:
            print("No data found for ASIN:", asin)

    print(review_list)


def csv_data():
    global review_list
    with open('amazon_data.csv', 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Review_ID', 'Review_Title', 'Review_comment'])

        for i in range(len(review_list['review_id'])):
            review_id = review_list['review_id'][i]
            review_title = review_list['review_title'][i]
            review_comment = review_list['review_comment'][i]
            writer.writerow([review_id, review_title, review_comment])
        print('CSV file created successfully.')


ids()
reviews()
csv_data()

# %% [markdown]
# # **Preprocessing Twitter and Amazon Data**
# To preprocess the Twitter and Amazon data and save the preprocessed data to a new CSV file, you can follow these steps:
#
# 1. Read the CSV file into a DataFrame using pd.read_csv('Twitter_and_Amazon_hp_data.csv').
# 2. Set up the stopwords set and tokenizer using ``stopwords_set = set(ENGLISH_STOP_WORDS)`` and ``vectorizer = TfidfVectorizer()``.
# 3. Define a preprocessing function to clean the text. This function should remove URLs, convert text to lowercase, remove punctuation, remove stopwords, and join the tokens back into a string.
# 4. Apply the preprocessing function to the 'Full Text' column of the DataFrame using ``df['Preprocessed Text'] = df['Full Text'].apply(preprocess_text)``.
# 5. Save the preprocessed data to a new CSV file using ``df.to_csv('preprocessed_data.csv', index=False)``.
# 6. Print a message indicating the completion of the preprocessing step, such as ``print('Preprocessing complete. Preprocessed data saved to preprocessed_data.csv.')``.
#
# Make sure to have the required libraries installed ``pandas, re, string, and sklearn`` and provide the correct input file path for the Twitter and Amazon data. After running the code, you will have a new CSV file named 'preprocessed_data.csv' containing the preprocessed data..

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('Twitter_and_Amazon_hp_data.csv')

# Set up stopwords and tokenizer
stopwords_set = set(ENGLISH_STOP_WORDS)
vectorizer = TfidfVectorizer()

# Preprocessing function
def preprocess_text(text):
    if isinstance(text, str):
        # Remove URLs
        text = re.sub(r"http\S+|www\S+|https\S+", "", text)
        
        # Convert to lowercase
        text = text.lower()
        
        # Remove punctuation
        text = ''.join([c for c in text if c not in punctuation])
        
        # Remove stopwords
        tokens = text.split()
        tokens = [token for token in tokens if token not in stopwords_set]
        
        # Join tokens back into a string
        preprocessed_text = ' '.join(tokens)
        
        return preprocessed_text
    else:
        return ""

# Apply preprocessing to the 'Full Text' column
df['Preprocessed Text'] = df['Full Text'].apply(preprocess_text)

# Save the preprocessed data to a new CSV file
df.to_csv('preprocessed_data.csv', index=False)

print('Preprocessing complete. Preprocessed data saved to preprocessed_tweets.csv.')

# %% [markdown]
# # **Sentiment Analysis of Preprocessed Data**
# To perform sentiment analysis on preprocessed tweets, you can use the following steps:
#
# 1. Initialize the sentiment analyzer, such as the VADER sentiment analyzer.
# 2. Define a function to analyze the sentiment of a given text using the sentiment analyzer. This function should return a sentiment score between -1 (negative) and 1 (positive).
# 3. Read the preprocessed tweet data from a CSV file into a DataFrame.
# 4. Access the column containing the preprocessed tweet text from the DataFrame.
# 5. Iterate over each preprocessed tweet and analyze its sentiment using the analyze_sentiment function.
# 6. Optionally, print the preprocessed tweet and its corresponding sentiment score for each tweet.
# 7. Collect the sentiment scores in a list for further analysis or visualization.
#
# Plot a histogram of the sentiment scores to visualize the distribution of sentiment in the preprocessed tweets.

# %%
# Initialize the sentiment analyzer
sid = SentimentIntensityAnalyzer()

def analyze_sentiment(text):
    """
    Analyzes the sentiment of the given text using VADER sentiment analysis.
    Returns a sentiment score between -1 (negative) and 1 (positive).
    """
    sentiment_scores = sid.polarity_scores(text)
    compound_score = sentiment_scores['compound']
    return compound_score

# Read the preprocessed data from the CSV file
data = pd.read_csv('preprocessed_data.csv')

# Access the 'review_text' column from the DataFrame
reviews = data['Preprocessed Text'].astype(str)

# Analyze sentiment for each review
for review in reviews:
    sentiment_score = analyze_sentiment(review)
    print(f"Review: {review}")
    print(f"Sentiment score: {sentiment_score}")
    print()

# Analyze sentiment for each review and collect the scores
sentiment_scores = []
for review in reviews:
    sentiment_score = analyze_sentiment(review)
    sentiment_scores.append(sentiment_score)

# Plot a histogram of the sentiment scores
plt.hist(sentiment_scores, bins=10, edgecolor='black')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Scores')
plt.show()
# Out:
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: mckinsey product academy offers real actionable insights product leaders register june 2 learn genai sustainability inclusive design revolutionizing product management
# Sentiment score: 0.0
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: explore benefits account abstraction interoperability solutions builders learn use cases epic web3 conference – l2 scaling solutions decentralized storage – interoperability security governance – zk account abstraction tokenomics ticket now🔥
# Sentiment score: 0.7506
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: developers hard reach impossible heres weve learned dev tool marketing far 👇
# Sentiment score: -0.0772
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: accumulating research shows lifelong stressors degrade health increase cancer risk exercise help counteract impact stress
# Sentiment score: -0.8834
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: effective organic super affordable gnomes powerful organic lawn care formulas just 99year ✅turns lawn lush green month ✅cheaper professional services ✅dries 424 hours ✅gets rid weeds good gnome lawncare fertilizer
# Sentiment score: 0.9423
#
# Review: headset glasses powerful standalone vr portable versatile performance handle heavyduty graphics pc streaming
# Sentiment score: 0.4215
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: accumulating research shows lifelong stressors degrade health increase cancer risk exercise help counteract impact stress
# Sentiment score: -0.8834
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: headset glasses powerful standalone vr portable versatile performance handle heavyduty graphics pc streaming
# Sentiment score: 0.4215
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: experience gaming like skytechs expertly built pcs backed 1year warranty lifetime support visit
# Sentiment score: 0.6486
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: hpsupport hpsupport reliancedigital need consumer court need local contact person hp india attend grave hp selling products does mention mail id contact person respon
# Sentiment score: -0.3818
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: mckinsey product academy offers real actionable insights product leaders register june 2 learn genai sustainability inclusive design revolutionizing product management
# Sentiment score: 0.0
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia registered complaint ur center got quotation silicon ur service partner paid upfront inexperienced engineer visit 4th day post payment n saying 3545 discontinued 5th day waiting sr engineer
# Sentiment score: -0.296
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: manmohankher hpindiamd hi manmohan hp privacy seriously protection ask send dm serial number unit ill look assist click link
# Sentiment score: -0.4939
#
# Review: hpindia ridiculous service n ridiculous hp products india look alternatives buying hp coz post sales service worst products
# Sentiment score: -0.8442
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: reasons attend work transformation summit emea 25 🌐 hear responsible ai implications human connection 🚀 master ai integration customer journey ⚖️ balance automation ethics rolling ai automation organisation
# Sentiment score: 0.3182
#
# Review: hpindia safe use products facing dangerous things 2weeks response provided company focus consumer safety jagograhakjago hpsupport hp bandbajaateraho
# Sentiment score: 0.3818
#
# Review: ga automatisch voor veel gb’s delen en blijf ondernemen met kpn zakelijk unlimited
# Sentiment score: 0.0
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: need reengineer process hpindia hpindiamd kempatel issue bluetooth driver missing month multiple hp devices installed office henceforth buying products hp
# Sentiment score: -0.296
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: 2031 group countries 5 10 remain friendly posture neutrality appears likely india
# Sentiment score: 0.4939
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: new lineup powerful powergpu prebuilt pcs available purchase ready elevate gaming experience new heights
# Sentiment score: 0.6486
#
# Review: headset glasses powerful standalone vr portable versatile performance handle heavyduty graphics pc streaming
# Sentiment score: 0.4215
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: accumulating research shows lifelong stressors degrade health increase cancer risk exercise help counteract impact stress
# Sentiment score: -0.8834
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: headset glasses powerful standalone vr portable versatile performance handle heavyduty graphics pc streaming
# Sentiment score: 0.4215
#
# Review: hpindia safe use products facing dangerous things 2weeks response provided company focus consumer safety jagograhakjago hpsupport hp bandbajaateraho
# Sentiment score: 0.3818
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: experience gaming like skytechs expertly built pcs backed 1year warranty lifetime support visit
# Sentiment score: 0.6486
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: win trust customers quality products thats exporting countries india hp ball clay high alumina clay good plasticity low shrinkage white clay best used glaze engobe compound double
# Sentiment score: 0.9201
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: solve major animal health challenges world faces today collaboration key 21 25 approx 600 country representatives animal health stakeholders gather paris 90th general session woahgs learn more👇
# Sentiment score: 0.2732
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: win shopping free buy 2 participating products pick n pay shop deals amp swipe enter tsampcs apply
# Sentiment score: 0.7717
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: genai sustainability inclusive design revolutionizing product management register virtual speaker series june 2 product leaders harnessing trends
# Sentiment score: 0.0
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: dog dad cool 👉 order ❣️ names appearances changed 5 dogs wanderprints bottle daddy father family dad fathersday fathersdaygift petlover doglover dog
# Sentiment score: 0.3182
#
# Review: accumulating research shows lifelong stressors degrade health increase cancer risk exercise help counteract impact stress
# Sentiment score: -0.8834
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: mckinsey product academy offers real actionable insights product leaders register june 2 learn genai sustainability inclusive design revolutionizing product management
# Sentiment score: 0.0
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: hpindia worst warranty service providing hp india days hearafter personally recommend hp products friends customers
# Sentiment score: 0.128
#
# Review: bought hp envy laptop oled touch 16h0028tx midjan 2023 far crashes tech expert came feb 28th replaced motherboard diagnostics test run 710 times hp support team hp worstexperiance hpindia hpsupport
# Sentiment score: 0.1531
#
# Review: astitvam don’t allow apple microsoft hp products india karnataka brands allowed sell karnataka gdp fall
# Sentiment score: 0.2263
#
# Review: hpindia hp hpsupport hpindiamd enriquejlores new fake procedures said entire internal hp crashed need improved restarted systematic hold selling products upgrade jagograhakj
# Sentiment score: 0.0
#
# Review: hpindia dont know services going really terrific does new purchased gaming laptops blank screen hp products nowadays
# Sentiment score: 0.5256
#
# Review: sandisk sony hpindia tnpoliceoffl mkstalin copy products usb pen drive circulation local mobile shop 👆 difficult identify original leading brands guess cover looking like original internal circu
# Sentiment score: 0.5574
#
# Review: yesbank hp yesrewardzprogram fraud reward program yes bank india sent fake hp laptop bag damaged verdical solutions india pvt partner packing hpindia enriquejlores pk63 counterfeit products payback rewards s
# Sentiment score: 0.1027
#
# Review: ／ 期間限定！セール実施中📢 ＼ 安心の国内生産でサポート充実なのにリーズナブル👛 用途に合わせてぴったりの一台が選べる💻✨ マウスコンピューター bto パソコン mouse 👇詳細はこちら
# Sentiment score: 0.0
#
# Review: rajivmakhni samsungindia hpindia lgindia products listed righttorepiar appliances think govt needs strict companies registering just theirs names website pmoindia narendra
# Sentiment score: 0.0
#
# Review: hpindia bought products u reputed company bought laptop 4 months ago facing problems complaint did proper solution support team 🤦🏻‍♂️ 3 years warranty h
# Sentiment score: 0.0258
#
# Review: enjoy stressfree brand planning amp virtual product launches leveraging platform strategic tactical amp launch planning meetings team experts ensures insights need delivered handcrafted reports
# Sentiment score: 0.4939
#
# Review: genai sustainability inclusive design revolutionizing product management register virtual speaker series june 2 product leaders harnessing trends
# Sentiment score: 0.0
#
# Review: hpindia poor service hp india future purchse products hp tell knownnot purchse hp product
# Sentiment score: -0.4767
#
# Review: hpindia hpsupport enriquejlores kempatel hpindiamd hp ashwinivaishnaw jagograhakjago consumerforum rubbish shameless customer service enriquejlores kempatel hour goes auto disconnected connected
# Sentiment score: -0.34
#
# Review: consumerforum forum india hp flipkart got damaged laptop flipkart think flipkart sells damaged products discounted price hp accepting laptop damage asking contact flipkart ridiculous service didn
# Sentiment score: -0.8271
#
# Review: hpindia hpindiamd vikas20011973 special request md hp india hpindiamd kindly look case harassment restore trust products hp
# Sentiment score: 0.7845
#
# Review: dont buy hp products desktop ki warranty krwane ke liye 1 year se pareshan hoo service center kahta log kro customer care bina engineer bheje bolta desktop koi issue nhi india se request h bhai bakwas service h dontbuyhp hp hpindia hpsupport hp consumer
# Sentiment score: 0.4939
#
# Review: hp hpindia hpsupport really unfortunate frustrating deal hp support buying hp laptop fault support does mental harassment customers products won’t service
# Sentiment score: -0.8059
#
# Review: case number 5097880432 thanks hp team mentally harassing amp false promises way u responded trust im going buy hp product amp suggest friendsfamily members amp upcoming future generation avoid hp products hp hpsupport hpindia
# Sentiment score: 0.5267
#
# Review: 5 reasons buy hp hpindia products 2023 1 poor hardware quality 2 poor hpsupport 3 poor sales warranty service 4 poor customer care relation 5 scamming customers mondaymorning mondayblues beyourbestyou scammers laptop newyear
# Sentiment score: -0.8481
#
# Review: ansh06417349590 did hear closing case need assistance hp products hesitate message great day stay safe😊 hp support
# Sentiment score: 0.6908
#
# Review: dear enriquejlores hp dont pressurize team hpindia maximize sell capable deliver services incompetent management team leading hpindia need proper long leave kindly approve leave stop selling ths products
# Sentiment score: 0.497
#
# Review: worst support experience hp far fix replacement hpindia recommend hp products based hp technical support experience hpindiamd
# Sentiment score: 0.4215
#
# Review: hpindia hope hp hpindia hpsupport great christmas amp new year hope year new year include fool customers escalation nightmares amp sad year called quality products
# Sentiment score: 0.5994
#
# Review: good product home use thing cost original ink cartridges higher printing cost 57 rs bw colour prints using original ink cartridges cartridge cost pages print
# Sentiment score: 0.7579
#
# Review: used wasted days install installation responding
# Sentiment score: -0.4939
#
# Review: product specifically sold cheap canon sell ink exorbitant prices plastic cheapest seen branded consumer product lost respect canon seeing flimsy nonhomogenous material aroundsome brilliant person decided fine chequered texture surface product predominantly sits open texture accumulates dust like magnet holds rest life surface holds sticker adhesive packing foam reside can’t clean ear bud soaked isopropyl alcoholthe description stated duplex printing paper tray automatic double sided printing need manual flip pages like prehistoric timesonce install associated canon software prepared bombarded notifications survey requests breath
# Sentiment score: 0.9325
#
# Review: instructions installing wifi print feature really confusing work imac finally installed android phone installed phone saw network imac good printer cheap price
# Sentiment score: 0.1796
#
# Review: best printer budget value money
# Sentiment score: 0.765
#
# Review: cartridge size small ink
# Sentiment score: 0.0
#
# Review: value money nahin hai
# Sentiment score: 0.34
#
# Review: biggest drawback ink doesnt long just took 10 prints black ink showing half emptywireless works perfectly finelittle complicated setup wireless worth effortthe printer surface catches dust easily
# Sentiment score: 0.8176
#
# Review: simple low cost solution printing home copies scans canon product easy install works wifi direct usb connection havent used negative observed controls printing scanning copying smartphone computer app printer bit cumbersome just want copy single page example overall good value money iwould buy need arises
# Sentiment score: 0.8933
#
# Review: negative concern1 actually slow printing2 huge printing costif manage ciss reduce3 black ink waterproof4 print quality good just ok quality5 duplex printing facility6 high price ₹4388positive concern1good wifi facility wps support direct connection mobile friendly quick connection plugin2can print paperphoto glossy 2 vinyl2easy efficient paper size selection3borderless printing4best printing resolution segment5good scanning resolution6cancel button immediately stop printscan oparation7 easy install8easy oparate plugin immediately connected devices wifi9small lcd display led notification
# Sentiment score: 0.9022
#
# Review: worth 13k inr product maximum priced 2000 inrdoes print skin tattoo use small printer head trayink doesnt work properly prints matter clean cartridge guidedapp printer sucks doesnt work print logos properly size adjustment problem appoverall 5 rating priced 2k inr price 13k inr worth 1 rating
# Sentiment score: 0.1027
#
# Review: dosto plz alart kyoki isme lotion ata hai itna paisa dene ke baad
# Sentiment score: 0.0772
#
# Review: excellent service good condition product sturdy packaging brief details use mbrush printer overall excellent service amazon
# Sentiment score: 0.9001
#
# Review: initially wanted return ink dry quick research youtube search mbrush troubleshooting got working intended basically need wipe printhead damp cloth use good color prints overall marvel tech smallest color printer print everwhere needs tinkering practice
# Sentiment score: 0.7506
#
# Review: amazing product great service
# Sentiment score: 0.836
#
# Review: quality isn’t amazing it’s pretty good started reading journal wanted print image book covers aren’t grainy color vibrant dark ones actually turned best far haven’t single issue i’m happy pictures recommend
# Sentiment score: 0.9741
#
# Review: artsy bullet journaling dont printer home great need pictures demand trips library printing connects quickly mobile app works sticker photos glossy slight discoloration screen overall happy output tiny images sheet dont come blurry
# Sentiment score: 0.0521
#
# Review: 221221 gekauft farbqualität ist ganz gut 3 bis 4 von 5 seit 1 monat macht das teil probleme schwierigkeiten beim anmachen erst nach mehreren versuchen geht das teilchen natürlich ist es aus der garantie raus 1 von 5von anfang fand ich die akku laufzeit etwas niedrig mich stört es nicht sollte man aber wissen falls man es viel unterwegs benutzen willich habe den 15 monaten ca 500 sticker ausgedruckt die qualität ist gleichbleibend hängt allerdings auch mit dem zinkpapier zusammenim gegensatz zu einer anderen rezension hier ist von meinen stickern noch keiner verblasst sie kleben auch immer noch super auch nach dem heißen sommersticker auf der rückseite vom handy ist natürlich abgenutzt dafür sind sie nur bedingt geeignetsie lassen sich auch ablösen glatter untergrund wie z b kühlschranktür und wieder aufkleben 5 von 5
# Sentiment score: -0.5994
#
# Review: bon les recharges sont chères mais ça le saitsinon qualité dimpression suffisante pour le format pratique dutilisation
# Sentiment score: 0.0
#
# Review: use natural light pictures exact blush color outputs look like size comparative hand 7 long middle finger
# Sentiment score: 0.802
#
# ...
# Sentiment score: 0.9186
#
# Review: printer good
# Sentiment score: 0.4404
#
# Review: ok
# Sentiment score: 0.296
#
# Review: best product
# Sentiment score: 0.6369
#
# Review: good hp
# Sentiment score: 0.4404
#
# Review: good product easy installfaster printerbest
# Sentiment score: 0.7003
#
# Review: item sealed transparent tape amazon tape cartridge lock delivered amazon parcel pack
# Sentiment score: 0.34
#
# Review: good product
# Sentiment score: 0.4404
#
# Review: nice
# Sentiment score: 0.4215
#
# Review: time print dark
# Sentiment score: 0.0
#
# Review: speed print good product
# Sentiment score: 0.4404
#
# Review: using product easy printers prints mobile slow prints fast mobile
# Sentiment score: 0.4404
#
# Review: hp printer 670 good product tech support hp fine discrimination product description given amazon product wrong1 bluetooth connerivity2 print speed 10ppm3 u used duplex printing print pdf booklet using landscape orientation print paper printed direction print upward 2nd paper print downward4 printing low colour shade
# Sentiment score: 0.7184
#
# Review: installation connectivity smooth guided quality doesnt feel like 8k doesnt mean bad excellent printer variant series hp headset free non adjustable comes headphones printer ink bottles packing need order separately
# Sentiment score: 0.2598
#
# Review: product ok overpriced compared brother features unless use app mobile laptop printer doesn’t intuitive buttons help improved big printer touch facilities availableanother thing id card feature doesn’t retain actual size makes difficult use govt offices software feature guess improvedproduct easy install comes nicely packed duplex feature good use mobile app extremely easy
# Sentiment score: 0.9442
#
# Review: hello purchased hp smart tank 670 printer amazon installation trained technician unable print double sided printing document print advise overcome issue procedures page printing feeder reversing second page print alignment problem suggest overcome thanks
# Sentiment score: 0.5574
#
# Review: hp smart tank 670 printer best quality printing fast print small issue paper tray smooth opening
# Sentiment score: 0.7845
#
# Review: little expensive covers aspect printing cooy needs far working printing nicely
# Sentiment score: 0.4404
#
# Review: print wifi problems times
# Sentiment score: -0.4019
#
# Review: expected early delivery delayed good
# Sentiment score: 0.25
#
# Review: printer good print quality good print speed okbut info shared amazon falseprinter doesnt support legal page printing mean feed legal page tray
# Sentiment score: 0.7097
#
# Review: अच्छा है किंतु सिंगल फोटो कापी होती है
# Sentiment score: 0.0
#
# Review: printerits meant regular heavy usethe ink provided wouldnt utilised years occasional useit stopped working half years low use ink dried line andor printer head suggest use printer head cleaning software option months using regularly avoid having printer issues clogged lines dried inkit doesnt print sides pages print page feed manually want print sides cumbersomeso consider printer feature duplex printing intend print large pages regular basis avoid wasting paper leaving unusedphoto printingi tried photos quality okay great expert dont experience photo printing homescannerits good complaint resolutionperformance sw user friendlyif document faded difficult choose best mode scan modes availablephotocopierworks colour black white modesonsitego warranty purchased printeri taken extended warranty 2 years onsitego repaired free chargestheir service smooth convenient picked delivered home day twoso quick convenient servicethe issue came onsitego pick guy didnt identity card authorisation letter company difficult ascertain authenticity service person whlle allowing printer away caused inconvenience handed unit phone calls email exchanges support teami recommend onsitego warranty particularly items like printers door step service case need overall good experience
# Sentiment score: 0.8683
#
# Review: produces noise lot printing quality fine comes printing glossy papers
# Sentiment score: 0.2023
#
# Review: happy purchase prints good connected wifi unsuccessful attempts doesnt recognise a4 sheet paperswhen tried legal paper works fine printer detects a4 recognising a4 a4this 2016 model im wrong got great reviews think sell refurbished goods new knowtip day u want printer try newer models interested brandsmuch better visit store directly buy checking working condition instead dealing purchasing waiting unboxing getting disappointed working return process waiting collected
# Sentiment score: 0.8807
#
# Review: good product
# Sentiment score: 0.4404
#
# Review: canon printer good taking school office workbut photos gets smudged month troubleshooting difficult count number blinks led light search tube solutionsuser clue whats wrong printer
# Sentiment score: -0.1779
#
# Review: good
# Sentiment score: 0.4404
#
# Review: high printing cost using 8 month time service issue warranty service centre charge 500 rupees spare parts
# Sentiment score: 0.0
#
# Review: wifi connectivity good configuration requires lot efforts print quality average
# Sentiment score: 0.4404
#
# Review: मैं कैफ़े चलाता हूं
# Sentiment score: 0.0
#
# Review: good product using couple month issue nice u
# Sentiment score: 0.6908
#
# Review: using weeks print quality good
# Sentiment score: 0.4404
#
# Review: think thermal printer best 3000 👍well packaging 👍easy install 👍
# Sentiment score: 0.6369
#
# Review: wast
# Sentiment score: 0.0
#
# Review: com thermal printeryah printer bahut hi achcha hai main ise bahut dinon se use kar raha hun meri ek emitra shop haiyah thermal printer aapko usb plus bluetooth donon variant mein aapko bahut hi lo price mein amazon dekhne ko mil jaega dostonदोस्तों यह प्रोडक्ट बहुत ही अच्छा है मैं इसे बहुत दिनों से यूज कर रहा हूं मेरी एक ईमित्र शॉप है और यह प्रोडक्ट यूएसबी प्लस ब्लूटूथ दोनों वेरिएंट में अमेज़न पर उपलब्ध हैं और यह बहुत ही लो प्राइस में आपको यहां पर मिल जाएगा दोस्तों आप इसे परचेस कर सकते हैं और बहुत ही अच्छा वर्क करता है दोस्तों और इसमें ज्यादा कॉस्ट अलग से रुपए भी नहीं लगते हैं और इसको स्टेशन करने में भी बहुत ही सरल और आसान है दोस्तों आप बिल्कुल से अपने फोन से या लैपटॉप से आसानी से इसमें प्रिंट निकाल कर पाएंगे दोस्तों बहुत ही अच्छा है आप इसे परचेस कर सकते हैंऔर दोस्तों आपको इस प्रिंटर का अनुभव रिव्यू मेरा वीडियो देखना हो तो आप मेरे यूट्यूब चैनलkn toolz mitpriya emitra helpline पर जा सकते हैं मेरे दोस्त है उन दोनों से पर अलगअलग वीडियो मैंने डाली है ब्लूटूथ और यूएसबी दोनों अलगअलग वीडियो मैंने अपने यूट्यूब पर अपलोड की है और आने वाले समय में इन प्रिंटर से जुड़े वीडियो में इस चैनल पर अपलोड कर लूंगा आप वहां जाकर हमारे चैनल को सब्सक्राइब करें और वहां जाकर आप इन वीडियो को आप देख सकते हैं
# Sentiment score: 0.1779
#
# Review: quality product superb provides lifetime free billing software software recommend everycom purchasing thermal printers
# Sentiment score: 0.872
#
# Review: printer working replace replacement working fine everycomm technical support team good guide nicely
# Sentiment score: 0.8519
#
# Review: cut function doent work
# Sentiment score: -0.2732
#
# Review: good customer sapport
# Sentiment score: 0.4404
#
# Review: good luck
# Sentiment score: 0.7096
#
# Review: reviewcomment
# Sentiment score: 0.0
#
# Review: reviewcomment
# Sentiment score: 0.0
#
# Review: reviewcomment
# Sentiment score: 0.0
#
# Review: nice machine working good need
# Sentiment score: 0.6908
#
# Review: dont buy printer cartridge size small costs half price printer refilled
# Sentiment score: 0.0
#
# Review: goodas expected
# Sentiment score: 0.0
#
# Review: working great
# Sentiment score: 0.6249
#
# Review: meet expectations specifications matching
# Sentiment score: 0.0
#
# Review: hp laserjet pro mfp m128fn printer ok cartridge 88a genuine operate given error supply error satisfied seller
# Sentiment score: -0.1027
#
# Review: good buy
# Sentiment score: 0.4404
#
# Review: wish negative stars
# Sentiment score: -0.25
#
# Review: nice productsame described
# Sentiment score: 0.4215
#
# Review: good
# Sentiment score: 0.4404
#
# Review: awesome product working gud
# Sentiment score: 0.6249
#
# Review: good nice
# Sentiment score: 0.6908
#
# Review: suitable
# Sentiment score: 0.0
#
# Review: good
# Sentiment score: 0.4404
#
# Review: value money
# Sentiment score: 0.34
#
# Review: onoff switch printer
# Sentiment score: 0.0
#
# Review: chaep
# Sentiment score: 0.0
#
# Review: facung problem repaired unable spare parts town
# Sentiment score: -0.4019
#
# Review: nice product easy use takes little time command
# Sentiment score: 0.6908
#
# Review: good printer
# Sentiment score: 0.4404
#
# Review: easy use
# Sentiment score: 0.4404
#
# Review: giving review using printer month genuine problem facingaccording hp support cartridge gets buy new toner printer chip oriented printer cost minimum rs3000 result high maintainance cost buyeraccording local market experts help changing chip worth rs 1000 wont guarantee work properly printer notso wont suggest buy printer
# Sentiment score: 0.644
#
# Review: color refilling problematic
# Sentiment score: -0.4404
#
# Review: halpfull teem fast shipping good products thanks
# Sentiment score: 0.7003
#
# Review: best home use works good wifi
# Sentiment score: 0.7964
#
# Review: hassle free printing cost best thing compact size initially face difficulty installation better hp installation support remote connection
# Sentiment score: 0.8934
#
# Review: bad experience purchasing hp laser printer 108w model reason toner ink gets finished option cartridgetoner refill option printer model option left purchasing new hp toner cost 3000 ideally cartridge refill cost 200300 rupees ho laser printer modelthe fact refill option totally hidden purchased online amazoneven hp service denied resolve issue printer model warranty period inspite concern documents provided amazon issue resolvenow
# Sentiment score: -0.0772
#
# Review: overall product good
# Sentiment score: 0.4404
#
# Review: value money complex install wifi
# Sentiment score: 0.34
#
# Review: amazing product thanks quick safe delivery amazon really want buy printer dont think twice packing perfectly intact item secured
# Sentiment score: 0.9617
#
# Review: nice printer
# Sentiment score: 0.4215
#
# Review: good printer
# Sentiment score: 0.4404
#
# Review: ordered week received immediately easy install beat hp printer segment problem cartridge costly
# Sentiment score: -0.0516
#
# Review: printer working page getting stuck
# Sentiment score: -0.25
#
# Review: printer good hp provice good customer service easy repair parts easily available market price printer mrp rate buy price
# Sentiment score: 0.8779
#
# Review: nan
# Sentiment score: 0.0
#
# Review: amazing printer model hit version performing appreciation 5 start👍
# Sentiment score: 0.7964
#
# Review: beat product daily use
# Sentiment score: 0.0
#
# Review: good quality easytouse
# Sentiment score: 0.4404
#
# Review: fast printing easy use print quality good waiting pages printed tonerits just app printing phone trust thr party apps
# Sentiment score: 0.8957
#
# Review: good product
# Sentiment score: 0.4404
#
# Review: good printer price point saves space small table
# Sentiment score: 0.4404
#
# Review: good laser printer good hp 1020 printing speed probably slightly slower really noticeable printing quality good hp 1020 rs 5000 available price discount steal having printer home run office 1015 employee printer hp 1020 ideal ones longterm maintenance requiredi dont suggest buy allinones unless routinely need scan print large blackandwhite document ideal printer singlefunction laser printers better multifunction deskjet ones
# Sentiment score: 0.9349
#
# Review: cd provided brokenwe want replaced immediately
# Sentiment score: 0.0772
#
# Review: good
# Sentiment score: 0.4404
#
# Review: printer good cost print quality print good choose quality print colour print good wifi connection fast scanner good good buy home use small business
# Sentiment score: 0.926
#
# Review: print quality good black white perfect people print color photo copy
# Sentiment score: 0.765
#
# Review: good product
# Sentiment score: 0.4404
#
# Review: effective easy operate helpful students daily usage home
# Sentiment score: 0.8316
#
# Review: dissapointed product dont touch itfirstly model listed website hp indiaafter searching installation software hp indonesia printer jams easily impossible print sides printed sheet 100 jamthis faillure model brought india
# Sentiment score: 0.34
#
# Review: connecting using mobile wifi
# Sentiment score: 0.0
#
# Review: initially issue amazon replaced product works good printing quality homekids school purpose best option
# Sentiment score: 0.8316
#
# Review: feels really cheap product terms handling terms features looks like using decade old technology setup easy non technical personprint quality good black color prints look dull
# Sentiment score: 0.6808
#
# Review: good printer having required functions optimum rate
# Sentiment score: 0.4404
#
# Review: good home use
# Sentiment score: 0.4404
#
# Review: worth price
# Sentiment score: 0.2263
#
# Review: day 1 review fyi super easy unpack set ready minutes did sample print pretty decent print qualityfive stars especially ease installation
# Sentiment score: 0.9441
#
# Review: perfect printer worth paid 10k inr special 10k similar features price wont recommend return policy product dont waste money
# Sentiment score: 0.8187
#
# Review: bought today installation simple product light weightprint quality good provide review month use
# Sentiment score: 0.4404
#
# Review: ordered product 14th nov delivered 16th nov afternoon print 1300 pages hp says single cartridge reduce print quality extent print quality bad 1 5 print quality scan quality good hp 11k product time does match price print scan quality output giving new printer rest thing say ok
# Sentiment score: 0.4588
#
# Review: product good worked perfectly till small problem come upsince product covered guarantee like technical come fix problem let know possible
# Sentiment score: 0.7351
#
# Review: cartridge gets pretty fast5060 pages thats itnot regular usershould read reviews buying
# Sentiment score: 0.4939
#
# Review: good printer use easily dislike distributor provide finished cartridges
# Sentiment score: 0.4019
#
# Review: print quality good installation slow able details
# Sentiment score: 0.4404
#
# Review: product good ink price highif buy hp805 ink4times buy printer second timebut wire shortbut product bad good
# Sentiment score: 0.3182
#
# Review: good printer personal use problem connectivity print quality issue theink used faster
# Sentiment score: 0.0516
#
# Review: really pair using mobile able pair mac using wifi direct limited instructions provided press buttons print instructions stored printer took time figure connection using usb instantaneous works just fine cartridge included printer displays cartridge left happy
# Sentiment score: 0.5574
#
# Review: weightless easy fix cartridge simple steps installed driver unlike thing able print wireless installing app
# Sentiment score: 0.4404
#
# Review: printer good cartridges gets fast tri color cartridges used printing 12 pcs a4 size paper single page paper ink quite expensive printer good reason recommend
# Sentiment score: 0.8074
#
# Review: mentioned description options best thing say printed 5 pages consider sarcasm
# Sentiment score: 0.5106
#
# Review: printer good goodbut print cost page highi got cd installation driverit print approx 160 colour 180 black
# Sentiment score: 0.4404
#
# Review: good quality print connectivity issues arises capability added network printer hp service real good problem occurred scanner came changed scanner assembly 1 disadvantage printer ink costly finished fast
# Sentiment score: -0.0258
#
# Review: purchased told print 500 copies printed 100copies showing cartidge
# Sentiment score: 0.0
#
# Review: giving review using 1 month definitely say printer fabulous quality prints good little bit hard install wont worry install manual guide provided
# Sentiment score: 0.9133
#
# Review: liked printer price quality free cartridge received printer defected buy new cartridge just black cartridge wasted 3 days thinking y prints r clear gave colour nd black white print separately figured black cartridge defect seller given
# Sentiment score: 0.1027

# %% [markdown]
# # **Sentiment Analysis and Knowledge Graph**
# This code performs sentiment analysis on new data and visualizes the sentiment scores and entities in a knowledge graph. It follows the following steps:
#
# 1. Define the Test Query.
# 2. Perform sentiment analysis using the VADER sentiment analysis tool.
# 3. Construct a knowledge graph using the networkx library.
# 4. Visualize the knowledge graph using the matplotlib library.
#
# The resulting knowledge graph provides insights into the sentiment distribution and relationships between entities and sentiments in the new data.

# %%
# Preprocess the new data and calculate sentiment scores
new_data = [
    "I'm having trouble with the wifi on printer model X.",
    "The printer brand Y is fantastic, never had any issues.",
    "Neutral post about printer model Z.",
]
sentiments = []
entities_occurrences = {}
sentiment_scores = {}

for text in new_data:
    sentiment_score = sid.polarity_scores(text)
    sentiment = 'appreciation' if sentiment_score['compound'] > 0 else 'complain' if sentiment_score['compound'] < 0 else 'suggestion'
    sentiments.append(sentiment)

    # Extract entities from the text
    tokens = nltk.word_tokenize(text)
    entities = [token.lower() for token in tokens if token.isalnum()]
    
    # Count the occurrence of each entity
    for entity in entities:
        entities_occurrences[entity] = entities_occurrences.get(entity, 0) + 1
    
    # Store sentiment scores
    sentiment_scores[sentiment] = sentiment_score['compound']

# Create a graph
G = nx.DiGraph()  # Use DiGraph for directed edges

# Iterate over each data point and its predicted sentiment
for data, sentiment in zip(new_data, sentiments):
    entities = ['wifi', 'printer model X', 'brand Y']  # Modify as needed based on your data

    # Add the sentiment node if it doesn't exist
    if sentiment not in G:
        G.add_node(sentiment, label='Sentiment')

    # Add the entities as nodes if they don't exist
    for entity in entities:
        if entity not in G:
            G.add_node(entity, label='Entity')

    # Add edges between the sentiment and entities with sentiment score as weight
    for entity in entities:
        weight = sentiment_scores[sentiment]
        G.add_edge(entity, sentiment, weight=weight)

# Set node positions using a circular layout
pos = nx.circular_layout(G)

# Set the figure size
plt.figure(figsize=(8, 8))

# Draw nodes and edges
node_colors = {'Sentiment': 'lightgray', 'Entity': 'lightgray', 'appreciation': 'lightgreen', 'suggestion': 'lightblue', 'complain': 'lightpink'}
nx.draw_networkx_nodes(G, pos, node_color=[node_colors[G.nodes[node]['label']] if 'label' in G.nodes[node] else node_colors[node] for node in G.nodes()], node_size=2000)

# Find the sentiment with the highest score
highest_sentiment = max(sentiment_scores, key=sentiment_scores.get)

# Draw edges with the highest sentiment score as weight
for u, v, data in G.edges(data=True):
    weight = data.get('weight', 0)
    if sentiment_scores[highest_sentiment] == max([data.get('weight', 0) for _, _, data in G.edges(data=True)]):
        nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], width=2.0, alpha=0.7, arrows=True)
        nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): f'{weight * 100:.2f}%'}, font_size=8)

nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold')

# Set labels and title
plt.xlabel('Entities')
plt.ylabel('Sentiments')
plt.title('Knowledge Graph')

# Show the graph
plt.show()
